# %%
import pandas as pd
import numpy as np
import pandas_profiling 
import matplotlib.pyplot as plt
import pickle 
from scipy.stats.mstats import winsorize

from pandas_datareader import data as pdr
import fix_yahoo_finance as yf
yf.pdr_override()

# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Qualification test
#    ### By Sokolov Gleb
#    ###  Job application @ ООО ИК QBF

# %% [markdown]
# ##### Аннотация

# %% [markdown]
#  Решение предложенного [квалификационного задания](https://github.com/QBQR/Trial-assignment) QBF. Сам ноутбук и код доступен в [репозитории](https://github.com/bakeryproducts/JA4QBF). Выполнено в Jupyter Notebook, использовались исключительно данные репозитория. Выбранная стратегия - Long/short equity, модель ранжирования - Listwise, реализация - Listnet. Ранжирование посекторное, на основе выбранных и построенных факторов.  Использованы методы машинного обучения пакетов Tensorflow, Keras. Вычисления проводились на ноутбуке, характеристики представлены ниже.
#  Далее на английском.

# %% [markdown]
#  Solution of trial assignment divided into three parts:

# %% [markdown]
# 1. Data analysis. Importing data from files, rearranging, visualising. EDA, basically. Using pandas,matplotlib,scipy
# 2. NN model. Building NN listnet model, visualising. Using Keras, Tensorflow, Tensorboard
# 3. Factor Analysis. Long/short equity algorithm. Using Alphalens, pandas

# %% [markdown]
# # Part 1. Data analysis

# %% [markdown]
# ## 1.0 Software versions, functions

# %%
pd.__version__
# Out:
# '0.23.4'

# %%
# %%bash
# archey3
# nvidia-smi
# Out:
#                +                OS: Arch Linux x86_64
#                #                Hostname: gleb-pc
#               ###               Kernel Release: 4.14.85-1-MANJARO
#              #####              Uptime: 6:35
#              ######             WM: Xfwm
#             ; #####;            DE: Xfce
#            +##.#####            Packages: 1158
#           +##########           RAM: 3135 MB / 7869 MB
#          #############;         Processor Type: Intel(R) Core(TM) i7-6500U CPU @ 2.50GHz
#         ###############+        $EDITOR: /usr/bin/nano
#        #######   #######        Root: 22G / 24G (91%) (ext4)
#      .######;     ;###;`".
#     .#######;     ;#####.
#     #########.   .########`
#    ######'           '######
#   ;####                 ####;
#   ##'                     '##
#  #'                         `#
#
# Thu Dec 13 20:10:22 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 415.18       Driver Version: 415.18       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 950M    Off  | 00000000:01:00.0 Off |                  N/A |
# | N/A   39C    P8    N/A /  N/A |      5MiB /  2004MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     11135      G   /usr/lib/Xorg                                  4MiB |
# +-----------------------------------------------------------------------------+

# %%
def adjsplit(price,scale,date):
    # adjusting factors for split 
    date = date +' 09:45:00'
    act_price = price[date:]
    corr_price = price[:date].iloc[:-1]/scale
    t = pd.concat([corr_price,act_price])
    return t

def setorder(tdf,col,ascending):
    # ranking function for 2d pandas df, ranking at 1 axis (by columns)
    dfs=[]
    for sector in sector_dict:
        rank_df= tdf.loc[:,(sector,slice(None),col)].rank(axis=1,pct=True,ascending=ascending)
        rank_df.columns = rank_df.columns.remove_unused_levels().set_levels(['rank'],level=2)

        #r_rank_df = rank_df.rolling(26*2).mean()
        #r_rank_df.columns = r_rank_df.columns.set_levels(['rank_r'],level=2)

        dfs.append(rank_df)
        #dfs.append(r_rank_df)
    
    ttdf = pd.concat(dfs,axis=1)
    return ttdf

def get_multiindex(df,col,name):
    # alias
    return df.loc[:,(slice(None),slice(None),col)].columns.remove_unused_levels().set_levels([name],level=2)

# %% [markdown]
# ## 1.1 Reading stocks data
#
# Reading stock tickers at sectors from `./data/sectors.csv`, combining them into dictionary.
# Dataframe with stock price and volume values is already preprocessed and loading from `./data/market_data_pd.pkl` file. Splits in stocks price and volume are settled with information from `./data/div_data.csv`

# %%
data_sectors = pd.read_csv('./data/sectors.csv').dropna()
sectors = data_sectors.INDUSTRY_SECTOR.value_counts()

# %%
sector_dict = {sector : data_sectors[data_sectors.INDUSTRY_SECTOR == sector].TICKER.values for sector in sectors.index}
ticker_dict = {ticker: sector for ticker,sector in zip(data_sectors.TICKER,data_sectors.INDUSTRY_SECTOR)}

# %%
# with open('./data/splits.pkl','rb') as f:
#     data_splits = pickle.load(f)
# columns_select = ['close','volume']
# ttdf = []
# for ticker,sector in ticker_dict.items():
#     tdf = pd.read_csv(f'./data/market_data/{ticker}.csv',index_col='dt')
#     tdf = tdf[columns_select].astype('float32')
#     tdf.columns = pd.MultiIndex.from_product([[sector],[ticker],tdf.columns])
#     try:
#         splits = data_splits[ticker]
#         print(sector,ticker,splits)
#         for split in splits:
#             tdf[(sector,ticker,'close')] = adjsplit(tdf[(sector,ticker,'close')],*split)        
#             tdf[(sector,ticker,'volume')] = adjsplit(tdf[(sector,ticker,'volume')],1/split[0],split[1])        

#     except Exception as e:
#         pass
#         #print('Error ',e)
#     ttdf.append(tdf)
        
# data = pd.concat(ttdf,axis=1,sort=True)
# data.index = pd.to_datetime(data.index)
# data = data.reindex(sorted(data.columns), axis=1)
# data.head()
# with open('./data/market_data_pd.pkl','wb') as f:
#     pickle.dump(data,f)

# %%
with open('./data/market_data_pd.pkl','rb') as f:
    data_all = pickle.load(f)
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52962 entries, 2010-01-04 09:45:00 to 2018-02-05 16:00:00
# Columns: 1318 entries, (Basic Materials, AA, close) to (Utilities, XEL, volume)
# dtypes: float32(1318)
# memory usage: 266.7 MB

# %%
# making sure on time range
start_day,end_day = '2010-01-01','2017-01-01'

data_all.index = (pd.to_datetime(data_all.index))
data_all = data_all.loc[start_day:end_day]
data_all.Financial.head()
# Out:
#                            ADS                  AFL                  AIG  \
#                          close    volume      close    volume      close
# 2010-01-04 09:45:00  65.330002   15070.0  46.759998  115171.0  29.590000
# 2010-01-04 10:00:00  65.519997   45276.0  46.669998  174109.0  29.719999
# 2010-01-04 10:15:00  65.330002   72475.0  46.680000  245607.0  29.680000
# 2010-01-04 10:30:00  65.519997   85560.0  46.740002  294065.0  29.570000
# 2010-01-04 10:45:00  65.620003  101309.0  46.909000  337560.0  29.700001
#
#                                       AIV                  AIZ            \
#                         volume      close    volume      close    volume
# 2010-01-04 09:45:00  1147007.0  16.290001   64897.0  29.690001   47027.0
# 2010-01-04 10:00:00  2084420.0  16.090000  145310.0  29.660000  108988.0
# 2010-01-04 10:15:00  2375095.0  15.970000  296005.0  29.817301  206136.0
# 2010-01-04 10:30:00  2599635.0  15.995000  355849.0  29.990000  251071.0
# 2010-01-04 10:45:00  2855516.0  16.059999  438577.0  30.010000  281943.0
#
#                        ...            WFC              WLTW                WY  \
#                        ...          close      volume close volume      close
# 2010-01-04 09:45:00    ...      27.030001   3261834.0   NaN    NaN  43.735001
# 2010-01-04 10:00:00    ...      27.040001   4732824.0   NaN    NaN  43.950001
# 2010-01-04 10:15:00    ...      27.010000   7967225.0   NaN    NaN  44.119999
# 2010-01-04 10:30:00    ...      27.170000   9686366.0   NaN    NaN  44.160000
# 2010-01-04 10:45:00    ...      27.100000  10544582.0   NaN    NaN  44.169998
#
#                                       XL              ZION
#                        volume      close    volume   close     volume
# 2010-01-04 09:45:00   69723.0  18.520000   89511.0  13.010   187980.0
# 2010-01-04 10:00:00  131253.0  18.530001  216917.0  13.040   384788.0
# 2010-01-04 10:15:00  206129.0  18.610001  317309.0  13.040   585942.0
# 2010-01-04 10:30:00  260583.0  18.600000  401601.0  13.045   785021.0
# 2010-01-04 10:45:00  320829.0  18.559999  483327.0  13.060  1080646.0
#
# [5 rows x 224 columns]

# %%
data_all.shape
# Out:
# (45812, 1318)

# %% [markdown]
# ## 1.2 Filtering data

# %% [markdown]
# Optional one can do data filtering. It goes under two criteria:
# 1. Volume
# 2. Price
#
# Volume criteria depends on certain quantile value for distribution of mean values for each stock, grouped by their sectors:
# $$V_{sector}^{stock} = \begin{cases}
#                               V_{sector}^{stock} & \text{, }E (V_{sector}^{stock})\ge [V_{Qsector}]\\
#                               \text{NaN}
#                        \end{cases}
# $$
#
#
# For pricing it is percentile drop between two trading days

# %%
# volume_q_limit,price_pct_limit = .1,.5

# data_vol = data_all.loc[:,(slice(None),slice(None),'volume')]
# volume_limit = data_vol.mean().groupby(level=0).quantile(volume_q_limit)
# vl_rule = [((data_vol[s].mean() >= volume_limit[s]).values) for s in sectors.keys()]
# volume_rule = [i for subl in vl_rule for i in subl]

# %%
# data_pri = data_all_range.loc[:,(slice(None),slice(None),'close')]
# price_rule = ((np.abs(data_pri.pct_change()[1:]) >= price_pct_limit).sum() == 0)#.values

# %%
# ticks = price_rule.index.get_level_values(1)
# rule = ticks[(volume_rule & price_rule)].values
# tdf = data_all.loc[:,(slice(None),rule)]
# data_filtered = tdf.loc[:,(tdf.isnull().sum()<200).values].dropna()

# %%
# letting in only data with enough actual data in it
data_all = data_all.loc[:,(data_all.isnull().sum()<200).values]
data_all = data_all.ffill()

# %%
data_filtered = data_all
del data_all

# %%
data_filtered.shape
# Out:
# (45812, 1040)

# %% [markdown]
# ## 1.3 Limiting stocks per sector
#
# For stability of predictions of our future NN model I will do sampling (per sector) on the stock data. So I randomly choose under N stocks in each sector.

# %%
n_tickers_by_sector = 20
chosen = []

for s in data_filtered.columns.levels[0]:
    temp_tickers = np.random.choice(data_filtered.loc[:,s].stack().columns,n_tickers_by_sector,replace=False)
    temp_tickers = np.unique(temp_tickers)
    chosen.append(data_filtered.loc[:,(slice(None),temp_tickers)])

data_n_by_sector = pd.concat(chosen,axis=1)
#data_n_by_sector = data_filtered

#those two started to get their Earnings data only at 2014 so...
banned_list=['CCE','MNST']
n_tickers = data_n_by_sector.columns.get_level_values(1).drop_duplicates()
try:
    for banned in banned_list:
        if banned in n_tickers:
            n_tickers = n_tickers.drop(banned)
except:
    pass


sect_lens = np.array([len(data_n_by_sector.loc[:,s].stack().columns) for s in data_n_by_sector.columns.levels[0] ])
del data_filtered
pd.DataFrame(sect_lens,index = pd.Index(list(sector_dict.keys()),name='Sector'),columns=['#']).T
# Out:
# Sector  Consumer, Non-cyclical  Financial  Consumer, Cyclical  Industrial  \
# #                           20         20                  20          20
#
# Sector  Technology  Energy  Communications  Utilities  Basic Materials
# #               20      20              20         20               20

# %% [markdown]
# ## 1.4 Advanced features
#
# Little bit of feature engineering;
# adding new features:
# 1. `r_sum` - rolling sum for difference of the price for one day;
# 2. `rank` - stock ranking for 'r_sum' within sector;
# 3. `rank_r` - rolling rank for approx. 3 month (one Q).
# 4. `mom` - price momentum

# %%
# Market guides for sectors, can be useful
# sector_indexs = {0:'XLF',1:'XLP',2:'XLI',3:'XLE',4:'XLB',5:'XLY',6:'XLC',7:'XLK',8:'XLU',9:'SPY'}
# d = pdr.get_data_yahoo(list(sector_indexs.values())[-1], start=start_day, end=end_day)
#d.Close.to_csv('./data/INDX.csv')

# %%
data_n_by_sector.shape
# Out:
# (45812, 360)

# %%
for t in n_tickers:
    #data_n_by_sector[ticker_dict[t],t,'r_sum2'] = data_n_by_sector[ticker_dict[t],t,'close'].diff().rolling(26*1).sum()
    data_n_by_sector[ticker_dict[t],t,'r_sum'] = data_n_by_sector[ticker_dict[t],t,'close'].diff().rolling(26*21).sum()

# As everywhere, 26 rows in 1 day, 21 day in a month
ts=1,26*21*1,26*21*12
rs = [data_n_by_sector.loc[:,(slice(None),slice(None),'close')].shift(t) for t in ts]
ms = ((rs[1]-rs[2])/rs[2] - (rs[0]-rs[1])/rs[1])#/np.nanstd(rs[0].diff(),axis=0)
ms.columns = get_multiindex(ms,'close','mom')
data_n_by_sector = pd.concat([data_n_by_sector,ms],axis=1)
del ms,rs
data_n_by_sector = data_n_by_sector.reindex(sorted(data_n_by_sector.columns), axis=1)
data_n_by_sector.shape
# Out:
# (45812, 720)

# %% [markdown]
# ## 1.5 Adding earnings data as features

# %% [markdown]
# It is time to have a look into additional data we have at `./data/eps_data` - there are Earning Per Share data win announcement dates for each stock.

# %% [markdown]
# EPS is not actualy a great thing to do later analysys on, so lets try rearrange this information. Additional features we can create from those:
# 1. `EPS_L4Q` - trailing EPS for last year
# 2. `SUE` - suprise rating, based on earnings estimates for quater
# 3. `Growth` - earning growth dynamics
# <br>(more info and code at `./data/EPS.ipynb`)

# %%
with open('./data/eps_data_list.pkl','rb') as f:
    EPSs = pickle.load(f)
    EPSs = {e:EPSs[e].loc[start_day:end_day] for e in EPSs if e in n_tickers}

# %%
l = [ticker_dict[ticker] for ticker in EPSs.keys()]
t = [pd.concat([df],keys = [ticker],axis=1) for ticker,df in EPSs.items()]
t = [pd.concat([df],keys = [sect],axis=1) for sect,df in zip(l,t)]

# EPS data goes beyond our pricing data, so:
EPSdf = pd.concat(t,axis=1)[:'2017']
EPSdf.dropna(axis=1, how='all',inplace=True)
del EPSs
EPSdf.Energy.iloc[:,:2].dropna().head()
# Out:
#                          APA
#                      EPS_L4Q     Growth
# Announcement Date
# 2010-11-04 16:00:00   8.2278   8.349341
# 2011-02-17 16:00:00   8.4998  -1.347697
# 2011-04-28 16:00:00   9.2812   8.857184
# 2011-08-04 16:00:00  10.1087  18.780629
# 2011-11-03 16:00:00  10.5317  12.180770

# %%
# making sure that tickers in EPS and pricing data are the same
tickers = EPSdf.columns.get_level_values(level=1).drop_duplicates()
data_full = data_n_by_sector.loc[:,(slice(None),tickers,slice(None))]

data_full = pd.concat([data_full,EPSdf],axis=1)
data_full = data_full.ffill()
data_full = data_full.reindex(sorted(data_full.columns), axis=1)

# P/E ratio thing, cliping it under 1000, pretty much random number
pe = data_full.loc[:,(slice(None),slice(None),'close')].values/data_full.loc[:,(slice(None),slice(None),'EPS_L4Q')].values
pe[pe<0] = 1000

pedf = pd.DataFrame(pe,index=data_full.index,columns = get_multiindex(data_full,'close','P/E'))
pedf = pedf.clip(upper=1000)

# PEG ratio, as is
peg = pe / data_full.loc[:,(slice(None),slice(None),'Growth')].values
pegdf = pd.DataFrame(peg,index=data_full.index,columns = get_multiindex(data_full,'close','PEG'))
# pegdf = pegdf.clip(upper=10)

data_full = pd.concat([pedf,pegdf,data_full],axis=1).astype('float32')
data_full = data_full.reindex(sorted(data_full.columns),axis=1)
del data_n_by_sector, pe, pedf,peg,pegdf#,EPSdf
# Out:
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in less
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## 1.6 Simple ranking

# %% [markdown]
# The idea is to rank each of predictive features across market within their sectors, then use those ranks as inputs for deep neural ranking net, based on listwise strategy. To improve individual rankings there are volatility measure and feature for boosting scores with momentum data.

# %%
# Getting some rating of volatility 
dfs={}
for s in sector_dict:
    vol = data_full.loc[:,(s,slice(None),'volume')][:]
    #vol[vol<0]=np.nan
    vol_std = vol.diff().rolling(26*21).std()
    dfs[s] = vol_std.mean(axis=1)
volatility_rating = pd.concat(dfs,axis=1)
volatility_rating = volatility_rating.div(volatility_rating.max(axis=1), axis=0)#.mean()
#volatility_rating.plot()

# %%
dfs = []

# Tensor for boosting ranking with good predictive feature, Momentum
# boost = 2*(data_full.loc[:,(slice(None),slice(None),'mom')].rank(axis=1,pct=True,ascending=False))-1
# boost = (1/(1-boost.abs())**9)
# boost = (1+boost.div(boost.max(axis=1), axis=0))

# ranking features
for c,asc in zip(['mom','P/E','PEG','r_sum'],[True,True,True,True]):
    df = 2*setorder(data_full,c,ascending=asc)-1
    #df = df*boost.values
#     for s in sector_dict:
#         df[s] = df[s].div(volatility_rating[s],axis=0)
    df.columns = df.columns.remove_unused_levels().set_levels([c+'_rank'],level=2)
    dfs.append(df)
ranks = pd.concat(dfs,axis=1)
del dfs
with open('./data/ranks.pkl','wb') as f:
    pickle.dump(ranks,f)

# %%
rank = ranks.groupby(level=1,axis=1).mean()
#w = (.3,.3,.3,.1)
#rank = t.dropna().groupby(level=1,axis=1).apply(lambda y: (y.iloc[:,0]*w[0] + w[1]*y.iloc[:,1] + y.iloc[:,2]*w[2] + y.iloc[:,3]*w[3]))
columns = get_multiindex(data_full,'close','rank')
rank_df = pd.DataFrame(rank.values,index=rank.index,columns=columns)
del ranks,rank

data_r = pd.concat([data_full,rank_df],axis=1).astype('float32')
data_r = data_r.reindex(sorted(data_r.columns), axis=1)

del rank_df

# %%
with open('./data/market.pkl','wb') as f:
    pickle.dump(data_r,f)

# %% [markdown]
# ## 1.7 Visualising

# %%
import pandas_profiling as pp

# %%
pp.ProfileReport(data_r.Technology.loc[:,('AAPL',slice(None))])
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>10 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>45817 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>6.2% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.9 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>44.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_('AAPL', 'EPS_L4Q')"><code>('AAPL', 'EPS_L4Q')</code></a> has 5199 / 11.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_('AAPL', 'Growth')"><code>('AAPL', 'Growth')</code></a> has 5199 / 11.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_('AAPL', 'P/E')"><code>('AAPL', 'P/E')</code></a> has 5199 / 11.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_('AAPL', 'PEG')"><code>('AAPL', 'PEG')</code></a> has 5199 / 11.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_('AAPL', 'mom')"><code>('AAPL', 'mom')</code></a> has 6552 / 14.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_('AAPL', 'r_sum')"><code>('AAPL', 'r_sum')</code></a> has 546 / 1.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_('AAPL', 'rank')"><code>('AAPL', 'rank')</code></a> has 546 / 1.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_('AAPL', 'rank')"><code>('AAPL', 'rank')</code></a> has 689 / 1.5% zeros <span class="label label-info">

# %%
data_r.Technology.loc[:,(slice(None),'r_sum')]['2015'].rank(axis=1,pct=True).iloc[:,:2].rolling(26*2).mean().plot(figsize=(15,7))

# %%
data_r.Technology.iloc[:,:9*5].loc[:,(slice(None),'rank')]['2012'].rolling(26).mean().plot(figsize=(15,7),title='One-day rolling ranks');

# %%
fig, axes = plt.subplots(1,1, figsize=(15,7), sharex=True)
(data_r.Technology.loc[:,(('CA'),('close'))]['2013':'2016']/15).plot(figsize=(15,7),ax=axes);
data_r.Technology.loc[:,(('CA'),('EPS_L4Q'))]['2013':'2016'].plot(figsize=(15,7),ax=axes);
axes.set_title('Close price and trailing EPS');

# %%
data_r.Technology.loc[:,(('CA','AAPL'),'r_sum')]['2013':'2016'].plot(figsize=(15,7),title='Cumulative sum of price returns');

# %%
se,ti = 'Technology','AAPL'
date1,date2 = '2016','2016'

fig, axes = plt.subplots(3,1, figsize=(10,7), sharex=True)
e = EPSdf[se][ti].dropna()[date1:date2].index
b = e - pd.Timedelta(hours=-24*3)
time_pairs = [(bi,ei) for ei,bi in zip(e,b)]

data_r.Technology.loc[:,(ti,['close'])].rolling(26).mean()[date1:date2].plot(figsize=(20,10),ax=axes[0],title='Close price on earnings day +3D');
data_r.Technology.loc[:,(ti,['rank'])].rolling(26).mean()[date1:date2].plot(figsize=(20,10),ax=axes[1],title = 'Mean rank on earnings day +3D');
data_r.Technology.loc[:,(ti,['volume'])].rolling(26).mean()[date1:date2].plot(figsize=(20,10),ax=axes[2],title = 'Volume on earnings day +3D');



[a.axvspan(*p,color='g',alpha=.2) for p in time_pairs for a in axes];

#data_full[se][ti][date1:date2]['rank_r'].dropna().plot(subplots = True,ax=axes);
